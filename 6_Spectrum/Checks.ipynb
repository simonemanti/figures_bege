# %%
import matplotlib.pyplot as plt
import numpy as np
import os, sys, pickle

# %%
# Load data
with open('../../data21_with_label_v2.pkl', 'rb') as f:
    df = pickle.load(f)

mask = (df['pred_label']==1)
spectrum_total = df['energy'].values
spectrum_good = df[mask]['energy'].values
spectrum_bad = df[~mask]['energy'].values
# Out:
# /tmp/ipykernel_10082/3297754536.py:3: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   df = pickle.load(f)

# %%
spectrum_total.shape, spectrum_good.shape, spectrum_bad.shape
# Out:
# ((22377,), (19464,), (2913,))

# %%
spectrum_bad.shape[0] / spectrum_total.shape[0]
# Out:
# 0.1301783080841936
